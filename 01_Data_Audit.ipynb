# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %%
file_path = "Sales Data-Jan'21 to Dec'21.xlsx"

df = pd.read_excel(file_path)

print("Dataset Loaded Successfully")
# Out:
# Dataset Loaded Successfully

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Rows: 78429
# Columns: 38

# %%
df.head()
# Out:
#   Customer Name  Customer Code  Ship To Cust Code Ship To Cust Name Bill Type  \
# 0  N.K. Traders       10016196           10016196      N.K. Traders      ZFAC
# 1  N.K. Traders       10016196           10016196      N.K. Traders      ZFAC
# 2  N.K. Traders       10016196           10016196      N.K. Traders      ZFAC
# 3  N.K. Traders       10016196           10016196      N.K. Traders      ZFAC
# 4  N.K. Traders       10016196           10016196      N.K. Traders      ZFAC
#
#      C      Inv.No           ODN BUS. PLACE       SO.No       Date  Week  \
# 0  NaN  2027009169  F22027008891       PH01  1129145721 2021-01-01     1
# 1  NaN  2027009169  F22027008891       PH01  1129145721 2021-01-01     1
# 2  NaN  2027009169  F22027008891       PH01  1129145721 2021-01-01     1
# 3  NaN  2027009169  F22027008891       PH01  1129145721 2021-01-01     1
# 4  NaN  2027009169  F22027008891       PH01  1129145721 2021-01-01     1
#
# ...

# %%
for col in df.columns:
    print(col)
# Out:
# Customer Name
# Customer Code
# Ship To Cust Code
# Ship To Cust Name
# Bill Type
# C
# Inv.No
# ODN
# BUS. PLACE
# SO.No
# Date
# Week
# Incoterms
# PO.No
# PI.No
# Cust.Nature
# Territory Code
# Territory
# Inv.Date
# Brand
# Sub-Brand
# Prime Brand
# Folder/Non-Folder
# Material
# Material Desc.
# Division
# Division Text
# Thickness
# Vol.CBM
# Design(LAM)
# Finish(LAM)
# Billed Qty
# Sales unit
# Billed Qty(SQM)
# Billed Qty(PCS)
# Billed Qty(NA)
# Billed Qty (CBM)
# Billed Qty (MT)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78429 entries, 0 to 78428
# Data columns (total 38 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Customer Name      78429 non-null  object
#  1   Customer Code      78429 non-null  int64
#  2   Ship To Cust Code  78429 non-null  int64
#  3   Ship To Cust Name  78429 non-null  object
#  4   Bill Type          78429 non-null  object
#  5   C                  1414 non-null   object
#  6   Inv.No             78429 non-null  int64
#  7   ODN                78429 non-null  object
#  8   BUS. PLACE         78429 non-null  object
#  9   SO.No              78429 non-null  int64
#  10  Date               78429 non-null  datetime64[ns]
#  11  Week               78429 non-null  int64
#  12  Incoterms          78429 non-null  object
#  13  PO.No              0 non-null      float64
#  14  PI.No              0 non-null      float64
#  15  Cust.Nature        78429 non-null  object
# ...

# %%
missing_values = pd.DataFrame({
    'Missing Values': df.isnull().sum(),
    'Percentage': round((df.isnull().sum()/len(df))*100,2)
})

missing_values.sort_values(
    by='Missing Values',
    ascending=False
)
# Out:
#                    Missing Values  Percentage
# Brand                       78429       100.0
# Finish(LAM)                 78429       100.0
# Folder/Non-Folder           78429       100.0
# PI.No                       78429       100.0
# PO.No                       78429       100.0
# Prime Brand                 78429       100.0
# Design(LAM)                 78429       100.0
# Sub-Brand                   78429       100.0
# C                           77015        98.2
# Sales unit                      0         0.0
# Billed Qty                      0         0.0
# Billed Qty(SQM)                 0         0.0
# Vol.CBM                         0         0.0
# Thickness                       0         0.0
# Billed Qty(PCS)                 0         0.0
# Billed Qty(NA)                  0         0.0
# Division Text                   0         0.0
# Division                        0         0.0
# Material Desc.                  0         0.0
# ...

# %%
duplicates = df.duplicated().sum()

print("Duplicate Records:", duplicates)
# Out:
# Duplicate Records: 79

# %%
unique_values = pd.DataFrame({
    'Column': df.columns,
    'Unique Values': [df[col].nunique() for col in df.columns]
})

unique_values.sort_values(
    by='Unique Values',
    ascending=False
)
# Out:
#                Column  Unique Values
# 6              Inv.No          14929
# 7                 ODN          14840
# 9               SO.No          13957
# 24     Material Desc.           5055
# 23           Material           5055
# 28            Vol.CBM           4176
# 36   Billed Qty (CBM)           4172
# 37    Billed Qty (MT)           2727
# 33    Billed Qty(SQM)           2027
# 34    Billed Qty(PCS)           1210
# 31         Billed Qty           1210
# 2   Ship To Cust Code           1097
# 3   Ship To Cust Name           1082
# 1       Customer Code            632
# 0       Customer Name            626
# 18           Inv.Date            359
# 10               Date            342
# 17          Territory             69
# 16     Territory Code             69
# 27          Thickness             30
# 4           Bill Type              9
# 12          Incoterms              8
# 11               Week              5
# 15        Cust.Nature              4
# ...

# %%
df.describe()
# Out:
#        Customer Code  Ship To Cust Code        Inv.No         SO.No  \
# count   7.842900e+04       7.842900e+04  7.842900e+04  7.842900e+04
# mean    1.002643e+07       1.002698e+07  2.076203e+09  1.173897e+09
# min     1.000006e+07       1.000006e+07  9.004280e+07  1.129142e+09
# 25%     1.001362e+07       1.001372e+07  2.027200e+09  1.129149e+09
# 50%     1.001452e+07       1.001547e+07  2.127004e+09  1.129153e+09
# 75%     1.001716e+07       1.001802e+07  2.127008e+09  1.129157e+09
# max     2.000044e+07       2.000044e+07  2.177300e+09  2.829110e+09
# std     2.825992e+05       2.825744e+05  2.311277e+08  1.555576e+08
#
#                                 Date          Week  PO.No  PI.No  \
# count                          78429  78429.000000    0.0    0.0
# mean   2021-07-01 16:29:09.393719040      2.826710    NaN    NaN
# min              2020-10-21 00:00:00      1.000000    NaN    NaN
# 25%              2021-03-11 00:00:00      2.000000    NaN    NaN
# ...

# %%
df.describe(include='all')
# Out:
#                Customer Name  Customer Code  Ship To Cust Code  \
# count                  78429   7.842900e+04       7.842900e+04
# unique                   626            NaN                NaN
# top     Sachdeva Enterprises            NaN                NaN
# freq                    3075            NaN                NaN
# mean                     NaN   1.002643e+07       1.002698e+07
# min                      NaN   1.000006e+07       1.000006e+07
# 25%                      NaN   1.001362e+07       1.001372e+07
# 50%                      NaN   1.001452e+07       1.001547e+07
# 75%                      NaN   1.001716e+07       1.001802e+07
# max                      NaN   2.000044e+07       2.000044e+07
# std                      NaN   2.825992e+05       2.825744e+05
#
#                Ship To Cust Name Bill Type     C        Inv.No           ODN  \
# count                      78429     78429  1414  7.842900e+04         78429
# ...

# %%
datatype_summary = pd.DataFrame({
    'Column': df.columns,
    'Data Type': df.dtypes
})

datatype_summary
# Out:
#                               Column       Data Type
# Customer Name          Customer Name          object
# Customer Code          Customer Code           int64
# Ship To Cust Code  Ship To Cust Code           int64
# Ship To Cust Name  Ship To Cust Name          object
# Bill Type                  Bill Type          object
# C                                  C          object
# Inv.No                        Inv.No           int64
# ODN                              ODN          object
# BUS. PLACE                BUS. PLACE          object
# SO.No                          SO.No           int64
# Date                            Date  datetime64[ns]
# Week                            Week           int64
# Incoterms                  Incoterms          object
# PO.No                          PO.No         float64
# PI.No                          PI.No         float64
# Cust.Nature              Cust.Nature          object
# Territory Code        Territory Code           int64
# ...

# %%
date_columns = df.select_dtypes(
    include=['datetime64[ns]']
).columns

print(date_columns)
# Out:
# Index(['Date', 'Inv.Date'], dtype='object')

# %%
important_columns = [
    'Territory',
    'Customer Name',
    'Material',
    'Division Text',
    'Thickness'
]

for col in important_columns:
    
    if col in df.columns:
        print("\n")
        print("="*50)
        print(col)
        print("="*50)
        
        print("Unique Values:", df[col].nunique())
        
        print(df[col].value_counts().head(10))
# Out:
# ...
# Territory
# ...
# Unique Values: 69
# Territory
# Prelam -Ghaziabad    13294
# Prelam -Delhi         9717
# Prelam-Ludhiana       9413
# Prelam -Jaipur        4796
# Prelam -Lucknow       4738
# Prejap1               3717
# Prelam -Gurgaon       3543
# Prelam -Ahmedabad     2806
# Prelam -Indore        2622
# Prelam -Chennai       2235
# Name: count, dtype: int64
#
#
# ...
# Customer Name
# ...
# Unique Values: 626
# Customer Name
# Sachdeva Enterprises                   3075
# Balaji Sales Corporation               2266
# Jaipur Bikaner Trading Company Agen    2149
# Gauri Nandan Wood Products             1436
# Sri Senthur tradings                   1413
# Mega Marketers                         1369
# HIND PLYWOOD                           1337
# Sehgal Plywood & Timber Merchants      1245
# Tanishka enterprises                   1177
# Banke bihari plywood agency            1114
# Name: count, dtype: int64
#
#
# ...
# Material
# ...
# Unique Values: 5055
# Material
# HMCI019PA24401220O    3275
# ...

# %%
volume_columns = [
    'Billed Qty',
    'Billed Qty(SQM)',
    'Billed Qty(PCS)',
    'Billed Qty(CBM)',
    'Billed Qty(MT)'
]

for col in volume_columns:
    
    if col in df.columns:
        
        print("\n")
        print(col)
        
        print("Total:", df[col].sum())
        print("Mean :", df[col].mean())
        print("Max  :", df[col].max())
# Out:
# Billed Qty
# Total: 9078372
# Mean : 115.75274452052174
# Max  : 5788
#
#
# Billed Qty(SQM)
# Total: 26695304.224
# Mean : 340.3754252126127
# Max  : 12922.289
#
#
# Billed Qty(PCS)
# Total: 9078372
# Mean : 115.75274452052174
# Max  : 5788

# %%
volume_columns = [
    'Billed Qty',
    'Billed Qty(SQM)',
    'Billed Qty(PCS)',
    'Billed Qty(CBM)',
    'Billed Qty(MT)'
]

for col in volume_columns:
    
    if col in df.columns:
        
        print("\n")
        print(col)
        
        print("Total:", df[col].sum())
        print("Mean :", df[col].mean())
        print("Max  :", df[col].max())
# Out:
# Billed Qty
# Total: 9078372
# Mean : 115.75274452052174
# Max  : 5788
#
#
# Billed Qty(SQM)
# Total: 26695304.224
# Mean : 340.3754252126127
# Max  : 12922.289
#
#
# Billed Qty(PCS)
# Total: 9078372
# Mean : 115.75274452052174
# Max  : 5788

# %%
drop_cols = [
    'PO.No',
    'PI.No',
    'Brand',
    'Sub-Brand',
    'Prime Brand',
    'Folder/Non-Folder',
    'Design(LAM)',
    'Finish(LAM)',
    'c'
]

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Rows: 78429
# Columns: 38

# %%
duplicates = df.duplicated().sum()

print("Duplicate Records:", duplicates)
# Out:
# Duplicate Records: 79

# %%
df = df.drop_duplicates()

print("New Shape:", df.shape)
# Out:
# New Shape: (78350, 38)

# %%
df['Inv.Date'] = pd.to_datetime(df['Inv.Date'])
df['Date'] = pd.to_datetime(df['Date'])

print(df['Inv.Date'].min())
print(df['Inv.Date'].max())
# Out:
# 2021-01-01 00:00:00
# 2021-12-31 00:00:00

# %%
df['Year'] = df['Inv.Date'].dt.year

df['Month'] = df['Inv.Date'].dt.month

df['Month_Name'] = df['Inv.Date'].dt.month_name()

df['Quarter'] = df['Inv.Date'].dt.quarter

df['Day'] = df['Inv.Date'].dt.day

df['Day_Name'] = df['Inv.Date'].dt.day_name()

# %%
df['Year_Month'] = df['Inv.Date'].dt.to_period('M').astype(str)

df[['Inv.Date', 'Year_Month']].head()
# Out:
#     Inv.Date Year_Month
# 0 2021-01-01    2021-01
# 1 2021-01-01    2021-01
# 2 2021-01-01    2021-01
# 3 2021-01-01    2021-01
# 4 2021-01-01    2021-01

# %%
df[['Year',
    'Month',
    'Month_Name',
    'Quarter',
    'Day',
    'Day_Name',
    'Year_Month']].head()
# Out:
#    Year  Month Month_Name  Quarter  Day Day_Name Year_Month
# 0  2021      1    January        1    1   Friday    2021-01
# 1  2021      1    January        1    1   Friday    2021-01
# 2  2021      1    January        1    1   Friday    2021-01
# 3  2021      1    January        1    1   Friday    2021-01
# 4  2021      1    January        1    1   Friday    2021-01

# %%
print("Total CBM Volume:")
print(df['Billed Qty (CBM)'].sum())

print("\nAverage Volume:")
print(df['Billed Qty (CBM)'].mean())
# Out:
# Total CBM Volume:
# 175154.15500000003
#
# Average Volume:
# 2.2355348436502873

# %%
business_summary = {
    "Total Records": len(df),
    "Customers": df['Customer Name'].nunique(),
    "Territories": df['Territory'].nunique(),
    "Materials": df['Material'].nunique(),
    "Divisions": df['Division Text'].nunique(),
    "Thickness Levels": df['Thickness'].nunique()
}

business_summary
# Out:
# {'Total Records': 78350,
#  'Customers': 626,
#  'Territories': 69,
#  'Materials': 5055,
#  'Divisions': 2,
#  'Thickness Levels': 30}

# %%
df.to_csv(
    "sales_cleaned.csv",
    index=False
)

print("Cleaned Dataset Saved Successfully")
# Out:
# Cleaned Dataset Saved Successfully
